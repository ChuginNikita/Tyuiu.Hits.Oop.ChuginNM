// %% [markdown]
// <h1 style="color:DodgerBlue">Индивидальный проект</h1>

// %% [markdown]
// <h2 style="color:DodgerBlue">Название проекта: Базовый менеджер задач</h2>
//
// ----
//
// ### Вариант 23

// %% [markdown]
// <h2 style="color:DodgerBlue">Описание проекта:</h2>
//
// ----
//
// [Создать базовый класс Task в C#, который будет представлять задачи внутри
// проекта. На основе этого класса разработать 2-3 производных класса,
// демонстрирующих принципы наследования и полиморфизма. В каждом из классов
// должны быть реализованы новые атрибуты и методы, а также переопределены
// некоторые методы базового класса для демонстрации полиморфизма.]

// %% [markdown]
// <h2 style="color:DodgerBlue">Реализация:</h2>
//
// ----

// %%
public class Task
{
    public int TaskId { get; set; }
    public string TaskName { get; set; }
    public string Priority { get; set; }
    public bool IsCompleted { get; protected set; }
    public string AssignedTo { get; protected set; }

    public Task(int taskId, string taskName, string priority)
    {
        TaskId = taskId;
        TaskName = taskName;
        Priority = priority;
        IsCompleted = false;
        AssignedTo = "Не назначен";
    }

    public virtual void MarkAsComplete()
    {
        IsCompleted = true;
    }

    public virtual string GetTaskDetails()
    {
        return $"ID: {TaskId}, Название: {TaskName}, Приоритет: {Priority}, Статус: {(IsCompleted ? "Выполнена" : "В процессе")}, Назначена: {AssignedTo}";
    }

    public virtual void ReassignTo(string newAssignee)
    {
        AssignedTo = newAssignee;
    }
}

public class DelegateTask : Task
{
    public DateTime DueDate { get; set; }

    public DelegateTask(int taskId, string taskName, string priority, DateTime dueDate)
        : base(taskId, taskName, priority)
    {
        DueDate = dueDate;
    }

    public override void MarkAsComplete()
    {
        IsCompleted = true;
    }

    public override string GetTaskDetails()
    {
        return base.GetTaskDetails() + $", Срок: {DueDate:yyyy-MM-dd}";
    }
}

public class TeamTask : Task
{
    public string TeamName { get; set; }

    public TeamTask(int taskId, string taskName, string priority, string teamName)
        : base(taskId, taskName, priority)
    {
        TeamName = teamName;
    }

    public override void ReassignTo(string newAssignee)
    {
        AssignedTo = newAssignee;
    }

    public override string GetTaskDetails()
    {
        return base.GetTaskDetails() + $", Команда: {TeamName}";
    }
}

public class ResearchTask : Task
{
    public string DataSource { get; set; }

    public ResearchTask(int taskId, string taskName, string priority, string dataSource)
        : base(taskId, taskName, priority)
    {
        DataSource = dataSource;
    }

    public override string GetTaskDetails()
    {
        return base.GetTaskDetails() + $", Источник данных: {DataSource}";
    }
}

DelegateTask delegateTask = new DelegateTask(1, "Документация", "Высокий", DateTime.Now.AddDays(5));
TeamTask teamTask = new TeamTask(2, "Аутентификация", "Критический", "Бэкенд");
ResearchTask researchTask = new ResearchTask(3, "Анализ данных", "Средний", "Google Analytics");

Console.WriteLine("ДО НАЗНАЧЕНИЯ:");
Console.WriteLine(delegateTask.GetTaskDetails());
Console.WriteLine(teamTask.GetTaskDetails());
Console.WriteLine(researchTask.GetTaskDetails());

Console.WriteLine();

delegateTask.ReassignTo("Анна");
teamTask.ReassignTo("Игорь");
researchTask.ReassignTo("Дмитрий");

Console.WriteLine("ПОСЛЕ НАЗНАЧЕНИЯ:");
Console.WriteLine(delegateTask.GetTaskDetails());
Console.WriteLine(teamTask.GetTaskDetails());
Console.WriteLine(researchTask.GetTaskDetails());

Console.WriteLine();

delegateTask.MarkAsComplete();
teamTask.MarkAsComplete();
researchTask.MarkAsComplete();

Console.WriteLine("ПОСЛЕ ВЫПОЛНЕНИЯ:");
Console.WriteLine(delegateTask.GetTaskDetails());
Console.WriteLine($"Выполнена: {delegateTask.IsCompleted}");

Console.WriteLine(teamTask.GetTaskDetails());
Console.WriteLine($"Выполнена: {teamTask.IsCompleted}");

Console.WriteLine(researchTask.GetTaskDetails());
Console.WriteLine($"Выполнена: {researchTask.IsCompleted}");
// Out:
// ДО НАЗНАЧЕНИЯ:
// ID: 1, Название: Документация, Приоритет: Высокий, Статус: В процессе, Назначена: Не назначен, Срок: 2026-09-28
// ID: 2, Название: Аутентификация, Приоритет: Критический, Статус: В процессе, Назначена: Не назначен, Команда: Бэкенд
// ID: 3, Название: Анализ данных, Приоритет: Средний, Статус: В процессе, Назначена: Не назначен, Источник данных: Google Analytics
//
// ПОСЛЕ НАЗНАЧЕНИЯ:
// ID: 1, Название: Документация, Приоритет: Высокий, Статус: В процессе, Назначена: Анна, Срок: 2026-09-28
// ID: 2, Название: Аутентификация, Приоритет: Критический, Статус: В процессе, Назначена: Игорь, Команда: Бэкенд
// ID: 3, Название: Анализ данных, Приоритет: Средний, Статус: В процессе, Назначена: Дмитрий, Источник данных: Google Analytics
//
// ПОСЛЕ ВЫПОЛНЕНИЯ:
// ID: 1, Название: Документация, Приоритет: Высокий, Статус: Выполнена, Назначена: Анна, Срок: 2026-09-28
// Выполнена: True
// ID: 2, Название: Аутентификация, Приоритет: Критический, Статус: Выполнена, Назначена: Игорь, Команда: Бэкенд
// Выполнена: True
// ID: 3, Название: Анализ данных, Приоритет: Средний, Статус: Выполнена, Назначена: Дмитрий, Источник данных: Google Analytics
// Выполнена: True
